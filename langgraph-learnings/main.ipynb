# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

# %%
from typing import TypedDict
from langgraph.graph import StateGraph, START, END

llm = init_chat_model("google_genai:gemini-flash-latest")
class State(TypedDict):
    messages: list

def chatbot(state: State) -> State:
    return {"messages": llm.invoke(state["messages"])}

builder = StateGraph(State)
builder.add_node("chatbot_node", chatbot)

builder.add_edge(START, "chatbot_node")
builder.add_edge("chatbot_node", END)
graph = builder.compile()

# %%
graph.invoke({"roles": ["user"], "messages": ["What is the capital of France?"]})
# Out:
# {'messages': AIMessage(content=[{'type': 'text', 'text': 'The capital of France is **Paris**.', 'extras': {'signature': 'Eq4BCqsBAb4+9vsDXLns1V9bHteMquDnzUQ8eTss8HkSFUqsGtf906hBDcZ6QGbv9WVfE9+6EHBoB2UaHd2Z+BA5uFoVriv0s8wxrhwGN3gDE2spsuc9CO0ORhZztzTLxZnbIUdrWf6PbTa0gdiCW0qVRSkPQwEQ6a+MEjdJaMTcK8PwNcJgF8lzXAIZkK4oBpFVu7remGCNu6NhVJNVN+09bH8hB2s0ERRF6U2BU/lt'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3-flash-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d6152-5822-7d11-bd7c-04bd8b4c7d6c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 38, 'total_tokens': 46, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 30}})}
